# %% [markdown]
# #**ASSIGNMENT**
# #**THEORY QUESTIONS**

# %% [markdown]
# #**Q1)What is a Support Vector Machine (SVM)?**
# #ans:-
# SVM are a machine learning algorithm which overcomes the disadvantages of Logistic regression and Linear regression. SVM's help decide the best fit decision boundry by using support vectors. The best fit line is equidistant from both marginal lines/plane. MArginal planes are made using support vectors.
# Support vectors are such datapoints which appear to be close to the decision boundry.

# %% [markdown]
# #**Q2)What is the difference between Hard Margin and Soft Margin SVM?**
# #ANS:-
# * Hard margins are the marginal lines or plane which are made using the closest data point to the decision boundry. This makes the gap between them very small which can lead to overfitting and sometimes even wrong classification of data.
#
# * Soft margins overcome the disadvantage of Hard margins by sacrificing some datapoints or by using some errors and we consider other data point as support vector to avoid overfitting and also get good accuracy ontest data.

# %% [markdown]
# #**Q3) What is the mathematical intuition behind SVM?**
# #ANS:-
# 🔹 1. Linear Separation Intuition:-
#
#
# Suppose you have two classes of points in a space (say red and blue dots). SVM tries to find a hyperplane (a line in 2D, a plane in 3D, etc.) that separates these classes.
#
# There are many possible separating hyperplanes, but SVM chooses the one with the maximum margin, i.e., the largest distance between the hyperplane and the nearest points from either class.
#
#
#
# 🔹 2. Mathematical Formulation:-
#
# ![image.png](data:image/png;base64,...)
#
#
# 🔹 3. Support Vectors:-
#
#
#
# Only the points closest to the hyperplane (i.e., those on the margin) affect the final decision boundary. These are called support vectors.
#
#
# 🔹 4. Non-Linear Separation:-
#
#
# If the data isn’t linearly separable, SVM uses the kernel trick to project data into a higher-dimensional space where linear separation is possible, without computing the transformation explicitly.
#
#
# 🔹 5. Soft Margin SVM (for noisy data):-
#
#
# Real-world data may not be perfectly separable, so we introduce slack variables and C to allow misclassifications:
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #**Q4)What is the role of Lagrange Multipliers in SVM?**
# #ANS:-
# 1. SVM has constraints like:
#
# ![image.png](data:image/png;base64,...)
#
#
# 2. To solve this with constraints, we use Lagrange multipliers αi , They help us build a new function (called the Lagrangian) that combines the goal and constraints:
#
# ![image.png](data:image/png;base64,...)
#
# 3. Then, we:
#
# * Minimize this function with respect to w and b
# * Maximize it with respect to αi
#
#
#
# 4. This leads to the dual problem, which is easier to solve — especially when we use kernels for non-linear data.
#
# 5. Only points with non-zero αi are support vectors — these define the decision boundary.

# %% [markdown]
# #**Q5)What are Support Vectors in SVM?**
# #ANS:-
# Support vectors are the datapoints which help define the best fit deicision boundry. These datapoints are close to the decision boundry. These marignal lines or plane help make decision boundry. Classifying support vectors should be in such a way find the best fit line which equidistant from both marginal lines or plane boundry.

# %% [markdown]
# #**Q6) What is a Support Vector Classifier (SVC)?**
# #ANS:-
# Support Vector classiifers are made for classification problem and we try to make to check if all the datapoints belong within the marginal boundries.We can handle non linera problems by using SVM kernels. We find the best hyperplane or boundry.

# %% [markdown]
# #**Q7)What is a Support Vector Regressor (SVR)?**
# #ANS:-
# Support Vector Regressor (SVR) is the regression version of SVM. Instead of classifying data, it tries to predict a continuous value while staying within a certain error margin (epsilon).
#
#
#
# ---> What SVR Does:
# * Tries to find a line (or curve) that fits the data.
# * Only cares about points outside the ε-tube (error margin).
# * Uses only these points (called support vectors) to define the model.
# * It classify values instead of classes.

# %% [markdown]
# #**Q8)What is the Kernel Trick in SVM?**
# #ANS:-
# Kernel trick or svm krenel is used to handle non linear relationship in SVM. we use diffrent mathemtical functions to segregate the data(like inc in dimesinality or square etc). It is called as a trick as instead of directly modfying the data we use some fucntion to achieve desired result.

# %% [markdown]
# #**Q9)Compare Linear Kernel, Polynomial Kernel, and RBF Kernel?**
# #ANS:-
# * Linear Kenrel:-
# A Linear Kernel is the simplest kernel used in SVM. It works when the data is linearly separable — meaning a straight line (or hyperplane) can divide the classes.
#
# FORMULA:-
# ![image.png](data:image/png;base64,...)
#
# * Polynomial Kernel:-
# The Polynomial Kernel allows SVM to create non-linear decision boundaries by mapping the input features into a higher-dimensional space using polynomial terms. Here d is degree of polynomial and c is constantGiven by:-
#
#
#
#
# ![image.png](data:image/png;base64,...)
#
# FORMULA:-
#
#
#
#
# ![image.png](data:image/png;base64,...)
#
#
# * RADIAL BASIS FUCNTION(RBF) Kernel:-
# Creates a non linear combination of features to bring you into higher dimension.
# It's formula is:-
#
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #**Q10)What is the effect of the C parameter in SVM?**
# #ANS:-
# C parameter can be also said as a regularization parameter.
#
#
# ![image.png](data:image/png;base64,...)
#
#
# It is used to overcome the problem of overfitting by sacrificing some datapoints in order to get a wider gap between both marginal lines or plane.
# The lesser the value of c, the better the model as it will be more accurate.

# %% [markdown]
# #**Q11)What is the role of the Gamma parameter in RBF Kernel SVM?**
# #ANS:-
# The gamma parameter in RBF Kernel SVM controls how much influence a single training point has on the decision boundary.
#
#
# ![image.png](data:image/png;base64,...)
#
#
# Low γ:-	Each point affects a large region	Smoother, more general
#
#
# High γ:-	Each point affects a small region	Tighter fit, may overfit

# %% [markdown]
# #**Q12)What is the Naïve Bayes classifier, and why is it called "Naïve"?**
# #ANS:-
# Naive Bayes classifier takes into assumption that each feature is independent of each other which is not practically right. That is why it is termed as Naives. Naive Bayes classifier is a algortihm in machine learning which uses bayes theoem.
#
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #**Q13)What is Bayes’ Theorem?**
# #ANS:-
# Bayes theorem is given by the formula:-
#
#
# ![image.png](data:image/png;base64,...)
#
# It tells us the probabilty of an event after an event has already occured.

# %% [markdown]
# #**Q14)Explain the differences between Gaussian Naïve Bayes, Multinomial Naïve Bayes, and Bernoulli Naïve Bayes?**
# #ANS:- We use the most used classifier in case of diffrent classifier in a singular data
#
# * Gaussian Naïve Bayes:- We use this classifier is used when data is continous and follow the normal distribution.
#
# * Multinomial Naïve Bayes:-We use it when the data is textual data. We use various NLP techniques to convert it into numeric number by vectors.
#
# * Bernoulli Naïve Bayes:- It is used when the data follows a bernoulli's distribtuion. It oftens leads to overfitting as sparse matrix is used.

# %% [markdown]
# #**Q15) When should you use Gaussian Naïve Bayes over other variants?**
# #ANS:-
# We use it when the data is shwoing a normal distribtuion. Used when the data is continous and follows a normal distribution.

# %% [markdown]
# #**Q16)What are the key assumptions made by Naïve Bayes?**
# #ANS:-
# THe main assumption is within it's name Naive. Naive indicates that each feature is independent of one another which is not practically right.It assumes that the data is following some kind of distribution. There is no collinearity present. all feature contribute equally to the output.

# %% [markdown]
# #**Q17) What are the advantages and disadvantages of Naïve Bayes?**
# #ANS:-
# #ADVANTAGE:-
# * Simple and fast to train and predict
# * Works well with small datasets
# * Effective for high-dimensional data (e.g., text)
# * Handles irrelevant features well
# * Less prone to overfitting
#
# #DISADVANTAGE:-
# * Assumes feature independence (often unrealistic)
# * Performs poorly with correlated features
# * Zero probability problem for unseen features
# * Less flexible for complex data patterns

# %% [markdown]
# #**Q18) Why is Naïve Bayes a good choice for text classification?**
# #ANS:-
# Naive Bayes is good for high dimensioanl data(text) as it uses Multinomila classifier for such data. It uses various NLP techniques to convert this text data into an numerical data(vectors)

# %% [markdown]
# #**Q19)Compare SVM and Naïve Bayes for classification tasks:**
# #ANS:-
# * SVM is a discriminative model; Naïve Bayes is a generative model
# * SVM makes no strong assumptions; Naïve Bayes assumes feature independence
# * SVM is slower to train; Naïve Bayes is very fast
# * SVM handles non-linear and complex data better
# * Naïve Bayes works well with text and categorical data
# * SVM supports kernels; Naïve Bayes does not
# * SVM can overfit without tuning; Naïve Bayes is less prone to overfitting
# * Naïve Bayes is easier to interpret than SVM
# * SVM handles correlated features well; Naïve Bayes does not

# %% [markdown]
# #**Q20)How does Laplace Smoothing help in Naïve Bayes?**
# #ANS:-
# * Prevents zero probability for unseen feature-class combinations
# * Adds a small constant (usually 1) to all counts
# * Ensures every probability > 0, improving model robustness
# * Especially useful in text classification with large vocabularies
# Formula after smoothing:(V=vocualbulary size)
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #**PRACTICAL QUESTIONS**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %%
#Q21)Write a Python program to train an SVM Classifier on the Iris dataset and evaluate accuracy:
from sklearn.datasets import load_iris
data=load_iris()
df=pd.DataFrame(data.data,columns=data.feature_names)
df['target']=data.target

# %%
X=df.iloc[:,:-1]
y=df.iloc[:,-1]
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=1)
from sklearn.svm import SVC
classifier=SVC()
classifier.fit(X_train,y_train)
y_pred=classifier.predict(X_test)
from sklearn.metrics import accuracy_score
print(accuracy_score(y_test,y_pred))
# Out:
# 0.9666666666666667

# %%
#Q22) Write a Python program to train two SVM classifiers with Linear and RBF kernels on the Wine dataset, then compare their accuracies:
from sklearn.datasets import load_wine
sup=load_wine()
df=pd.DataFrame(sup.data,columns=sup.feature_names)
df['target']=sup.target

# %%
X=df.iloc[:,:-1]
y=df.iloc[:,-1]
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=1)
#linear kernel
class1=SVC(C=1,kernel='linear')
class1.fit(X_train,y_train)
y_pred1=class1.predict(X_test)

#RBF kernel
class2=SVC(C=1,gamma='scale',kernel='rbf')
class2.fit(X_train,y_train)
y_pred2=class2.predict(X_test)
print(f'LInear KErnel accuracy score:',{accuracy_score(y_test,y_pred1)})
print(f'RBF KErnel accuracy score:',{accuracy_score(y_test,y_pred2)})
# Out:
# LInear KErnel accuracy score: {0.9444444444444444}
# RBF KErnel accuracy score: {0.6388888888888888}

# %%
#Q23)Write a Python program to train an SVM Regressor (SVR) on a housing dataset and evaluate it using Mean Squared Error (MSE)
from sklearn.datasets import fetch_california_housing
house=fetch_california_housing()
df=pd.DataFrame(house.data,columns=house.feature_names)
df['target']=house.target

# %%
df
# Out:
#        MedInc  HouseAge  AveRooms  ...  Latitude  Longitude  target
# 0      8.3252      41.0  6.984127  ...     37.88    -122.23   4.526
# 1      8.3014      21.0  6.238137  ...     37.86    -122.22   3.585
# 2      7.2574      52.0  8.288136  ...     37.85    -122.24   3.521
# 3      5.6431      52.0  5.817352  ...     37.85    -122.25   3.413
# 4      3.8462      52.0  6.281853  ...     37.85    -122.25   3.422
# ...       ...       ...       ...  ...       ...        ...     ...
# 20635  1.5603      25.0  5.045455  ...     39.48    -121.09   0.781
# 20636  2.5568      18.0  6.114035  ...     39.49    -121.21   0.771
# 20637  1.7000      17.0  5.205543  ...     39.43    -121.22   0.923
# 20638  1.8672      18.0  5.329513  ...     39.43    -121.32   0.847
# 20639  2.3886      16.0  5.254717  ...     39.37    -121.24   0.894
#
# [20640 rows x 9 columns]

# %%
X=df.iloc[:,:-1]
y=df.iloc[:,-1]
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=1)
from sklearn.svm import SVR
model=SVR()
model.fit(X_train,y_train)
y_pred=model.predict(X_test)
from sklearn.metrics import mean_squared_error
print(mean_squared_error(y_test,y_pred))
# Out:
# 1.320732383526986

# %%
#Q24) Write a Python program to train an SVM Classifier with a Polynomial Kernel and visualize the decision boundary:
from sklearn.datasets import make_classification
X, y = make_classification(n_samples=200, n_features=2, n_informative=2, n_redundant=0,n_clusters_per_class=1, random_state=1)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1)
model = SVC(kernel='poly', degree=3, C=1.0)
model.fit(X_train, y_train)
def plot_decision_boundary(model, X, y, title):
      x_min, x_max = X[:, 0].min() - 1, X[:, 0].max() + 1#Calculate ranges for plotting
      y_min, y_max = X[:, 1].min() - 1, X[:, 1].max() + 1
      xx, yy = np.meshgrid(np.linspace(x_min, x_max, 300),np.linspace(y_min, y_max, 300))#We Plotting the gri region right now,
      grid = np.c_[xx.ravel(), yy.ravel()]#contains the gird points in 2d format
      Z = model.predict(grid).reshape(xx.shape)#is reshaped back to match the shape of the plot grid.
      plt.contourf(xx, yy, Z, cmap=plt.cm.coolwarm, alpha=0.5)#Fills the background with different colors based on prediction (class 0 or 1).
      plt.scatter(X[:, 0], X[:, 1], c=y, cmap=plt.cm.coolwarm, edgecolors='k')
      plt.title(title)
      plt.xlabel("Feature 1")
      plt.ylabel("Feature 2")
      plt.show()
plot_decision_boundary(model, X_test, y_test, "SVM with Polynomial Kernel (Test Set)")#plot_decision_boundary(model, X_test, y_test, "SVM with Polynomial Kernel (Test Set)")

# %%
#Q25)Write a Python program to train a Gaussian Naïve Bayes classifier on the Breast Cancer dataset and evaluate accuracy
from sklearn.datasets import load_breast_cancer
data=load_breast_cancer()
df=pd.DataFrame(data.data,columns=data.feature_names)
df['target']=data.target
X=df.iloc[:,:-1]
y=df.iloc[:,-1]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1)
from sklearn.naive_bayes import GaussianNB
model = GaussianNB()
model.fit(X_train, y_train)
y_pred=model.predict(X_test)
print(accuracy_score(y_test,y_pred))
# Out:
# 0.9473684210526315

# %%
#Q26)Write a Python program to train a Multinomial Naïve Bayes classifier for text classification using the 20 Newsgroups dataset.
from sklearn.datasets import fetch_20newsgroups
feet=fetch_20newsgroups()
print(feet.DESCR)
# Out:
# .. _20newsgroups_dataset:
#
# The 20 newsgroups text dataset
# ------------------------------
#
# The 20 newsgroups dataset comprises around 18000 newsgroups posts on
# 20 topics split in two subsets: one for training (or development)
# and the other one for testing (or for performance evaluation). The split
# between the train and test set is based upon a messages posted before
# and after a specific date.
#
# This module contains two loaders. The first one,
# :func:`sklearn.datasets.fetch_20newsgroups`,
# returns a list of the raw texts that can be fed to text feature
# extractors such as :class:`~sklearn.feature_extraction.text.CountVectorizer`
# with custom parameters so as to extract feature vectors.
# The second one, :func:`sklearn.datasets.fetch_20newsgroups_vectorized`,
# returns ready-to-use features, i.e., it is not necessary to use a feature
# extractor.
#
# **Data Set Characteristics:**
#
# =================   ==========
# Classes                     20
# ...

# %%
from sklearn.datasets import fetch_20newsgroups
from sklearn.feature_extraction.text import CountVectorizer#Converts raw text into bag-of-words format (word counts for each document).
from sklearn.naive_bayes import MultinomialNB


# 1. Load the 20 Newsgroups dataset
newsgroups = fetch_20newsgroups(subset='all', shuffle=True, random_state=1)# shullfe data randomly__>shuffle,subset-->which part of data to load

# 2. Split into training and test sets
X_train, X_test, y_train, y_test = train_test_split(newsgroups.data, newsgroups.target, test_size=0.2, random_state=1)

# 3. Convert text into numeric features using CountVectorizer
vectorizer = CountVectorizer()
X_train_counts = vectorizer.fit_transform(X_train)
X_test_counts = vectorizer.transform(X_test)

# 4. Train the Multinomial Naive Bayes classifier
model = MultinomialNB()
model.fit(X_train_counts, y_train)

# 5. Make predictions
y_pred = model.predict(X_test_counts)

accuracy = accuracy_score(y_test, y_pred)
print(f"Accuracy: {accuracy:.2f}\n")
# Out:
# Accuracy: 0.85

# %%
#Q27)Write a Python program to train an SVM Classifier with different C values and compare the decision boundaries visually

C=[1,2,3]
X, y = make_classification(n_samples=200, n_features=2, n_informative=2, n_redundant=0, random_state=1)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1)
for i, C in enumerate(C):
    model = SVC(kernel='linear', C=C)
    model.fit(X_train, y_train)

    # Create a mesh grid
    x_min, x_max = X[:, 0].min() - 1, X[:, 0].max() + 1
    y_min, y_max = X[:, 1].min() - 1, X[:, 1].max() + 1
    xx, yy = np.meshgrid(np.linspace(x_min, x_max, 200),
                         np.linspace(y_min, y_max, 200))

    # Predict on mesh
    Z = model.predict(np.c_[xx.ravel(), yy.ravel()])
    Z = Z.reshape(xx.shape)

    # Plot
    plt.subplot(1, 3, i+1)
    plt.contourf(xx, yy, Z, alpha=0.3, cmap=plt.cm.coolwarm)
    plt.scatter(X[:, 0], X[:, 1], c=y, cmap=plt.cm.coolwarm, edgecolor='k')
    plt.title(f"C = {C}")
    plt.xticks([])
    plt.yticks([])

plt.tight_layout()
plt.show()

# %%
#Q28)Write a Python program to train a Bernoulli Naïve Bayes classifier for binary classification on a dataset with binary features
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')
from sklearn.datasets import make_classification
from sklearn.model_selection import train_test_split
X, y = make_classification(n_samples=100,n_features=4,n_informative=2,n_redundant=0,n_classes=2,random_state=1) #output is o and 1 meaning it follows binary classification
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1)

from sklearn.naive_bayes import BernoulliNB
model=BernoulliNB()
model.fit(X_train,y_train)
y_pred=model.predict(X_test)
from sklearn.metrics import accuracy_score
print(accuracy_score(y_test,y_pred))
# Out:
# 0.95

# %%
#Q29)Write a Python program to apply feature scaling before training an SVM model and compare results with unscaled data
X, y = make_classification(n_samples=1000,n_features=6,n_informative=4,n_redundant=2,n_classes=4,random_state=1) #output is o and 1 meaning it follows binary classification
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1)
from sklearn.preprocessing import StandardScaler
scaling=StandardScaler()
#before scaling
from sklearn.svm import SVC
model1=SVC()
model1.fit(X_train,y_train)
y_pred1=model1.predict(X_test)
print(f'The accuracy before scaling:',{accuracy_score(y_test,y_pred1)})

#after scaling
X_scaled_train=scaling.fit_transform(X_train)
X_scaled_test=scaling.transform(X_test)
model2=SVC()
model2.fit(X_scaled_train,y_train)
y_pred2=model2.predict(X_test)
print(f'The accuracy after scaling:',{accuracy_score(y_test,y_pred2)})
# Out:
# The accuracy before scaling: {0.74}
# The accuracy after scaling: {0.69}

# %%
#Q30)Write a Python program to train a Gaussian Naïve Bayes model and compare the predictions before and after Laplace Smoothing
#before
from sklearn.naive_bayes import GaussianNB
X, y = make_classification(n_samples=100, n_features=4, n_classes=2, random_state=1)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
y_pred = gnb.predict(X_test)
print("GaussianNB Accuracy:", accuracy_score(y_test, y_pred))
#after Gaussian does not allow laplace smoothing, so we use eiter mulitnomila or bernoiliNB
#taking same datasets
from sklearn.naive_bayes import BernoulliNB
bnb=BernoulliNB(alpha=0.0)#no laplace smoothing
bnb.fit(X_train,y_train)
y_pred1=bnb.predict(X_test)
print(f'The accuracy before smoothing:',{accuracy_score(y_test,y_pred1)})
bnb2=BernoulliNB(alpha=1.0)#laplace smoothing
bnb2.fit(X_train,y_train)
y_pred2=bnb2.predict(X_test)
print(f'The accuracy after smoothing:',{accuracy_score(y_test,y_pred2)})
# Out:
# GaussianNB Accuracy: 0.9333333333333333
# The accuracy before smoothing: {0.9333333333333333}
# The accuracy after smoothing: {0.9333333333333333}

# %%
#Q31)Write a Python program to train an SVM Classifier and use GridSearchCV to tune the hyperparameters (C,gamma, kernel)
param={'C':[1,2,3],'gamma':[0.1,1,2],'kernel':['linear','rbf','poly']}
from sklearn.model_selection import GridSearchCV
X, y = make_classification(n_samples=1000, n_features=6, n_classes=2, random_state=1)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=1)
model=SVC()
grid=GridSearchCV(model,param_grid=param,cv=3,verbose=2)
grid.fit(X_train,y_train)
# Out:
# Fitting 3 folds for each of 27 candidates, totalling 81 fits
# [CV] END ......................C=1, gamma=0.1, kernel=linear; total time=   0.0s
# [CV] END ......................C=1, gamma=0.1, kernel=linear; total time=   0.0s
# [CV] END ......................C=1, gamma=0.1, kernel=linear; total time=   0.0s
# [CV] END .........................C=1, gamma=0.1, kernel=rbf; total time=   0.0s
# [CV] END .........................C=1, gamma=0.1, kernel=rbf; total time=   0.0s
# [CV] END .........................C=1, gamma=0.1, kernel=rbf; total time=   0.0s
# [CV] END ........................C=1, gamma=0.1, kernel=poly; total time=   0.0s
# [CV] END ........................C=1, gamma=0.1, kernel=poly; total time=   0.0s
# [CV] END ........................C=1, gamma=0.1, kernel=poly; total time=   0.0s
# [CV] END ........................C=1, gamma=1, kernel=linear; total time=   0.0s
# [CV] END ........................C=1, gamma=1, kernel=linear; total time=   0.0s
# ...

# %%
grid.best_params_
# Out:
# {'C': 3, 'gamma': 0.1, 'kernel': 'rbf'}

# %%
grid.best_score_
# Out:
# np.float64(0.8785505545162198)

# %%
#Q32)Write a Python program to train an SVM Classifier on an imbalanced dataset and apply class weighting and check it improve accuracy
X, y = make_classification(n_samples=1000, n_features=6, n_classes=2, random_state=1,weights=[0.9,0.1])
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=1)
model=SVC()
model.fit(X_train,y_train)
y_pred=model.predict(X_test)
print(f'The accuracy on imbalanced:',{accuracy_score(y_test,y_pred)})
#for balaced dataset
model1=SVC(class_weight='balanced')
model1.fit(X_train,y_train)
y_pred1=model1.predict(X_test)
print(f'The accuracy on balanced:',{accuracy_score(y_test,y_pred1)})
# Out:
# The accuracy on imbalanced: {0.94}
# The accuracy on balanced: {0.87}

# %%
#Q33)Write a Python program to implement a Naïve Bayes classifier for spam detection using email data
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.naive_bayes import MultinomialNB

emails = [
    "Win money now!",                     # spam
    "Lowest price on medication",         # spam
    "Hi there, are we still on for lunch?", # not spam
    "Important information about your account",  # not spam
    "Congratulations, you won a lottery!", # spam
    "Can you send the report by today?",   # not spam
    "Buy one get one free!",              # spam
    "Let's catch up this weekend",        # not spam
]

labels = [1, 1, 0, 0, 1, 0, 1, 0]
vectorizer = CountVectorizer()
X = vectorizer.fit_transform(emails)
X_train, X_test, y_train, y_test = train_test_split(X, labels, test_size=0.3, random_state=42)
model = MultinomialNB()
model.fit(X_train, y_train)
y_pred = model.predict(X_test)
print("Accuracy:", accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.3333333333333333

# %%
#Q34)Write a Python program to train an SVM Classifier and a Naïve Bayes Classifier on the same dataset and compare their accuracy
X, y = make_classification(n_samples=1000, n_features=6, n_classes=2, random_state=1)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=1)
model=SVC()
model.fit(X_train,y_train)
y_pred=model.predict(X_test)
print("Accuracy for SVC:", accuracy_score(y_test, y_pred))

from sklearn.naive_bayes import GaussianNB
model1 =GaussianNB()
model1.fit(X_train, y_train)
y_pred1 = model1.predict(X_test)
print("Accuracy for GaussianNB:", accuracy_score(y_test, y_pred1))
# Out:
# Accuracy for SVC: 0.87
# Accuracy for GaussianNB: 0.81

# %%
#Q35)Write a Python program to perform feature selection before training a Naïve Bayes classifier and compare results
from sklearn.feature_selection import SelectKBest, chi2
from sklearn.preprocessing import MinMaxScaler

X, y = make_classification(n_samples=1000, n_features=20, n_classes=2, random_state=1)
X = MinMaxScaler().fit_transform(X)  # Make data non-negative for MultinomialNB

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

model1 = MultinomialNB()
model1.fit(X_train, y_train)
pred1 = model1.predict(X_test)
print("Accuracy without feature selection:", accuracy_score(y_test, pred1))

# Feature selection (top 10 features)
selector = SelectKBest(chi2, k=10)#using chi2 to get best features
X_train_sel = selector.fit_transform(X_train, y_train)
X_test_sel = selector.transform(X_test)
model2 = MultinomialNB()
model2.fit(X_train_sel, y_train)
pred2 = model2.predict(X_test_sel)
print("Accuracy with feature selection:", accuracy_score(y_test, pred2))
# Out:
# Accuracy without feature selection: 0.7133333333333334
# Accuracy with feature selection: 0.73

# %%
#Q36)Write a Python program to train an SVM Classifier using One-vs-Rest (OvR) and One-vs-One (OvO) strategies on the Wine dataset and compare their accuracy
from sklearn.multiclass import OneVsOneClassifier,OneVsRestClassifier
from sklearn.datasets import load_wine
data=load_wine()
df=pd.DataFrame(data.data,columns=data.feature_names)
df['target']=data.target
X=df.iloc[:,:-1]
y=df.iloc[:,-1]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1)
model=SVC(kernel='linear')
ovr_model=OneVsRestClassifier(model)
ovr_model.fit(X_train,y_train)
y_pred1=ovr_model.predict(X_test)
print("Accuracy with feature selection:", accuracy_score(y_test, y_pred1))
ovo_model=OneVsOneClassifier(model)
ovo_model.fit(X_train,y_train)
y_pred2=ovo_model.predict(X_test)
print("Accuracy with feature selection:", accuracy_score(y_test, y_pred2))
# Out:
# Accuracy with feature selection: 0.9444444444444444
# Accuracy with feature selection: 0.9444444444444444

# %%
#Q37)Write a Python program to train an SVM Classifier using Linear, Polynomial, and RBF kernels on the Breast Cancer dataset and compare their accuracy
from sklearn.datasets import load_breast_cancer
data=load_breast_cancer()
df=pd.DataFrame(data.data,columns=data.feature_names)
df['target']=data.target
X=df.iloc[:,:-1]
y=df.iloc[:,-1]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1)
#linear
model1=SVC(kernel='linear')
model1.fit(X_train, y_train)
y_pred1 = model1.predict(X_test)
print("Accuracy for linear kernel:", accuracy_score(y_test, y_pred1))
#Polynomial
model2=SVC(kernel='poly',degree=3,C=1)
model2.fit(X_train, y_train)
y_pred2 = model2.predict(X_test)
print("Accuracy for poly kernel:", accuracy_score(y_test, y_pred2))
#RBF
model3=SVC(kernel='rbf',C=1)
model3.fit(X_train, y_train)
y_pred3 = model3.predict(X_test)
print("Accuracy for rbf kernel:", accuracy_score(y_test, y_pred3))
# Out:
# Accuracy for linear kernel: 0.956140350877193
# Accuracy for poly kernel: 0.8947368421052632
# Accuracy for rbf kernel: 0.9035087719298246

# %%
#Q38) Write a Python program to train an SVM Classifier using Stratified K-Fold Cross-Validation and compute the average accuracy
from sklearn.model_selection import StratifiedKFold
X, y = make_classification(n_samples=1000, n_features=20, n_classes=2, random_state=1)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1)

# Stratified K-Fold setup
skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)
accuracies = []

# Split and train manually using the folds
for train_idx, test_idx in skf.split(X, y):
    X_train = X[train_idx]
    X_test = X[test_idx]
    y_train = y[train_idx]
    y_test = y[test_idx]

    # Train SVM
    clf = SVC(kernel='linear')
    clf.fit(X_train, y_train)

    # Predict and calculate accuracy
    y_pred = clf.predict(X_test)
    acc = accuracy_score(y_test, y_pred)
    accuracies.append(acc)

# Print results
print("Fold Accuracies:", accuracies)
print("Average Accuracy:", np.mean(accuracies))
# Out:
# Fold Accuracies: [0.86, 0.785, 0.84, 0.85, 0.865]
# Average Accuracy: 0.8400000000000001

# %%
#Q39)Write a Python program to train a Naïve Bayes classifier using different prior probabilities and compare performance
X, y = make_classification(n_samples=1000, n_features=20, n_classes=2, random_state=1)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42, stratify=y)

# Default prior (None)
model_default = GaussianNB()
model_default.fit(X_train, y_train)
pred_default = model_default.predict(X_test)
acc_default = accuracy_score(y_test, pred_default)

#prior(must be sum =1)
model_prior=GaussianNB(priors=[0.3,0.7])
model_prior.fit(X_train, y_train)
pred_prior = model_prior.predict(X_test)
acc_prior = accuracy_score(y_test, pred_prior)
print(f'Accuracy Deafult:',{acc_default},'\nAccuracy with prior prob:',{acc_prior})
# Out:
# Accuracy Deafult: {0.8066666666666666}
# Accuracy with prior prob: {0.7866666666666666}

# %%
#Q40) Write a Python program to perform Recursive Feature Elimination (RFE) before training an SVM Classifier and compare accuracy
from sklearn.feature_selection import RFE
from sklearn.datasets import load_breast_cancer
data=load_breast_cancer()
df=pd.DataFrame(data.data,columns=data.feature_names)
df['target']=data.target
X=df.iloc[:,:-1]
y=df.iloc[:,-1]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1)
#DEaFULT
model=SVC(kernel='linear')
model.fit(X_train,y_train)
y_pred=model.predict(X_test)
acc_2=accuracy_score(y_test,y_pred)
#USING RFE
rfe=RFE(model,n_features_to_select=5)
X_rfe=rfe.fit_transform(X_train,y_train)
X_test_rfe=rfe.transform(X_test)
model1=SVC()
model1.fit(X_rfe,y_train)
y_pred1=model1.predict(X_test_rfe)
acc_1=accuracy_score(y_test,y_pred1)
print(f'Accuracy Deafult:',{acc_2},'\nAccuracy with RFE:',{acc_1})
# Out:
# Accuracy Deafult: {0.956140350877193}
# Accuracy with RFE: {0.8771929824561403}

# %%
#Q41)Write a Python program to train an SVM Classifier and evaluate its performance using Precision, Recall, and F1-Score instead of accuracy
from sklearn.datasets import load_breast_cancer
data=load_breast_cancer()
df=pd.DataFrame(data.data,columns=data.feature_names)
df['target']=data.target
X=df.iloc[:,:-1]
y=df.iloc[:,-1]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1)
model=SVC(kernel='linear')
model.fit(X_train,y_train)
y_pred=model.predict(X_test)
from sklearn.metrics import f1_score,recall_score,precision_score
print("f1:", f1_score(y_test, y_pred))
print('recall:', recall_score(y_test, y_pred))
print("precision:", precision_score(y_test, y_pred))
# Out:
# f1: 0.9664429530201343
# recall: 1.0
# precision: 0.935064935064935

# %%
#Q42)Write a Python program to train a Naïve Bayes Classifier and evaluate its performance using Log Loss (Cross-Entropy Loss)
X, y = make_classification(n_samples=1000, n_features=20, n_classes=2, random_state=1)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1)
model=GaussianNB()
model.fit(X_train,y_train)
y_pred=model.predict(X_test)
from sklearn.metrics import log_loss
print("log loss:", log_loss(y_test, y_pred))
# Out:
# log loss: 5.226329741421987

# %%
#Q43)Write a Python program to train an SVM Classifier and visualize the Confusion Matrix using seaborn
X, y = make_classification(n_samples=1000, n_features=20, n_classes=2, random_state=1)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1)
model=GaussianNB()
model.fit(X_train,y_train)
y_pred=model.predict(X_test)
from sklearn.metrics import confusion_matrix
cm=confusion_matrix(y_test,y_pred)
sns.heatmap(cm,annot=True)
plt.title("Confusion Matrix")
plt.show()

# %%
#Q44)Write a Python program to train an SVM Regressor (SVR) and evaluate its performance using Mean Absolute Error (MAE) instead of MSE
from sklearn.datasets import make_regression
X, y = make_regression(n_samples=100, n_features=1, noise=10, random_state=1)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1)
from sklearn.svm import SVR
model=SVR()
model.fit(X_train,y_train)
y_pred=model.predict(X_test)
from sklearn.metrics import mean_absolute_error
print("MAE:", mean_absolute_error(y_test, y_pred))
# Out:
# MAE: 45.84629673816973

# %%
#Q45)Write a Python program to train a Naïve Bayes classifier and evaluate its performance using the ROC-AUC score
from sklearn.datasets import make_classification
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import roc_auc_score, roc_curve
import matplotlib.pyplot as plt

# Step 1: Generate a binary classification dataset
X, y = make_classification(n_samples=1000, n_features=20,
                           n_informative=10, n_redundant=5,
                           random_state=1)

# Step 2: Split into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y,
                                                    test_size=0.3,
                                                    random_state=1)


model = GaussianNB()
model.fit(X_train, y_train)

y_prob = model.predict_proba(X_test)[:, 1]  # Probabilities for class 1

roc_auc = roc_auc_score(y_test, y_prob)
print(f"ROC-AUC Score: {roc_auc:.4f}")
fpr, tpr, _ = roc_curve(y_test, y_prob)

plt.plot(fpr, tpr, label=f'Naïve Bayes (AUC = {roc_auc:.2f})')
plt.plot([0, 1], [0, 1], linestyle='--', color='gray')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# ROC-AUC Score: 0.9165

# %%
#Q46)Write a Python program to train an SVM Classifier and visualize the Precision-Recall Curve.
from sklearn.datasets import make_classification
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.metrics import precision_recall_curve, average_precision_score
import matplotlib.pyplot as plt

# Step 1: Generate a binary classification dataset
X, y = make_classification(n_samples=1000, n_features=20,
                           n_informative=10, n_redundant=5,
                           random_state=42)

# Step 2: Train/test split
X_train, X_test, y_train, y_test = train_test_split(X, y,
                                                    test_size=0.3,
                                                    random_state=42)

# Step 3: Train an SVM classifier with probability estimates
model = SVC(kernel='rbf', probability=True, random_state=42)
model.fit(X_train, y_train)

# Step 4: Get predicted probabilities
y_scores = model.predict_proba(X_test)[:, 1]

# Step 5: Compute precision and recall
precision, recall, _ = precision_recall_curve(y_test, y_scores)
avg_precision = average_precision_score(y_test, y_scores)

# Step 6: Plot Precision-Recall curve
plt.plot(recall, precision, label=f'AP = {avg_precision:.2f}')
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title('Precision-Recall Curve (SVM)')
plt.legend()
plt.grid(True)
plt.show()
